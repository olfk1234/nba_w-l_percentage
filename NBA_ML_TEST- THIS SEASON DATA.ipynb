# %%
from joblib import load
model = load("C:\\Users\\ganes\\Downloads\\final_NBA_win_pct_model.joblib")

# %%
scaler = load("C:\\Users\\ganes\\Downloads\\final_NBA_win_pct_model_scaler.joblib")

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ganes\\Downloads\\Jan_4_Updated_NBA.csv")

# %%
X = df.drop("W/L%", axis = 1)
y = df["W/L%"]

# %%
X = scaler.fit_transform(X)

# %%
y_pred = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mean_absolute_error(y, y_pred)
# Out:
# 0.04843218919608431

# %%
import numpy as np
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# 0.06312818827566084

# %%
df
# Out:
#      W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A
# 0   0.703  6.27  119.17  112.75  6.42   6.03  119.43  113.25    6.18
# 1   0.632  5.24  116.04  110.58  5.46   5.03  115.87  110.59    5.28
# 2   0.639  4.33  114.78  110.45  4.33   4.60  114.58  110.01    4.58
# 3   0.676  4.35  117.27  112.78  4.49   4.31  117.35  112.89    4.47
# 4   0.622  4.46  116.21  111.76  4.45   4.29  115.79  111.53    4.26
# 5   0.611  3.89  114.74  110.82  3.93   3.63  114.80  111.12    3.68
# 6   0.526  2.84  115.93  112.95  2.98   2.68  115.80  112.96    2.84
# 7   0.526  2.50  117.32  114.86  2.45   2.60  117.40  114.89    2.51
# 8   0.579  2.32  116.78  114.41  2.37   2.23  116.67  114.40    2.27
# 9   0.639  1.75  112.79  110.94  1.85   1.76  112.87  110.98    1.89
# 10  0.649  1.89  118.11  116.31  1.80   1.36  117.50  116.26    1.23
# 11  0.543  1.26  116.36  115.28  1.08   1.28  116.62  115.52    1.10
# 12  0.487  0.67  116.87  116.44  0.43   0.73  117.01  116.55    0.46
# ...

# %%
y_pred
# Out:
# array([0.76719893, 0.72413163, 0.68394436, 0.68705763, 0.68308862,
#        0.66208012, 0.62076005, 0.60432358, 0.59668186, 0.57662961,
#        0.56661252, 0.54821356, 0.52101895, 0.50033092, 0.52492634,
#        0.49194128, 0.49561296, 0.4825789 , 0.45625188, 0.47288224,
#        0.48328914, 0.45320087, 0.44865959, 0.43246209, 0.42747502,
#        0.31752981, 0.22299534, 0.20449873, 0.22615278, 0.10979512])

# %%
df["W/L % Predictions"] = y_pred

# %%
df
# Out:
#      W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A  \
# 0   0.703  6.27  119.17  112.75  6.42   6.03  119.43  113.25    6.18
# 1   0.632  5.24  116.04  110.58  5.46   5.03  115.87  110.59    5.28
# 2   0.639  4.33  114.78  110.45  4.33   4.60  114.58  110.01    4.58
# 3   0.676  4.35  117.27  112.78  4.49   4.31  117.35  112.89    4.47
# 4   0.622  4.46  116.21  111.76  4.45   4.29  115.79  111.53    4.26
# 5   0.611  3.89  114.74  110.82  3.93   3.63  114.80  111.12    3.68
# 6   0.526  2.84  115.93  112.95  2.98   2.68  115.80  112.96    2.84
# 7   0.526  2.50  117.32  114.86  2.45   2.60  117.40  114.89    2.51
# 8   0.579  2.32  116.78  114.41  2.37   2.23  116.67  114.40    2.27
# 9   0.639  1.75  112.79  110.94  1.85   1.76  112.87  110.98    1.89
# 10  0.649  1.89  118.11  116.31  1.80   1.36  117.50  116.26    1.23
# 11  0.543  1.26  116.36  115.28  1.08   1.28  116.62  115.52    1.10
# 12  0.487  0.67  116.87  116.44  0.43   0.73  117.01  116.55    0.46
# ...

# %%
df["W_pred"] = y_pred * 82

# %%
df["L_pred"] = round(82-df["W_pred"],0)

# %%
df
# Out:
#      W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A  \
# 0   0.703  6.27  119.17  112.75  6.42   6.03  119.43  113.25    6.18
# 1   0.632  5.24  116.04  110.58  5.46   5.03  115.87  110.59    5.28
# 2   0.639  4.33  114.78  110.45  4.33   4.60  114.58  110.01    4.58
# 3   0.676  4.35  117.27  112.78  4.49   4.31  117.35  112.89    4.47
# 4   0.622  4.46  116.21  111.76  4.45   4.29  115.79  111.53    4.26
# 5   0.611  3.89  114.74  110.82  3.93   3.63  114.80  111.12    3.68
# 6   0.526  2.84  115.93  112.95  2.98   2.68  115.80  112.96    2.84
# 7   0.526  2.50  117.32  114.86  2.45   2.60  117.40  114.89    2.51
# 8   0.579  2.32  116.78  114.41  2.37   2.23  116.67  114.40    2.27
# 9   0.639  1.75  112.79  110.94  1.85   1.76  112.87  110.98    1.89
# 10  0.649  1.89  118.11  116.31  1.80   1.36  117.50  116.26    1.23
# 11  0.543  1.26  116.36  115.28  1.08   1.28  116.62  115.52    1.10
# 12  0.487  0.67  116.87  116.44  0.43   0.73  117.01  116.55    0.46
# ...

# %%
# df = df.drop("Final_Record_Pred", axis = 1)

# %%
df.W_pred = df.W_pred.round()
df.L_pred = df.L_pred.round()

# %%
df["W_pred"] = df["W_pred"].astype("int32")
df["L_pred"] = df["L_pred"].astype("int32")

# %%
df
# Out:
#      W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A  \
# 0   0.703  6.27  119.17  112.75  6.42   6.03  119.43  113.25    6.18
# 1   0.632  5.24  116.04  110.58  5.46   5.03  115.87  110.59    5.28
# 2   0.639  4.33  114.78  110.45  4.33   4.60  114.58  110.01    4.58
# 3   0.676  4.35  117.27  112.78  4.49   4.31  117.35  112.89    4.47
# 4   0.622  4.46  116.21  111.76  4.45   4.29  115.79  111.53    4.26
# 5   0.611  3.89  114.74  110.82  3.93   3.63  114.80  111.12    3.68
# 6   0.526  2.84  115.93  112.95  2.98   2.68  115.80  112.96    2.84
# 7   0.526  2.50  117.32  114.86  2.45   2.60  117.40  114.89    2.51
# 8   0.579  2.32  116.78  114.41  2.37   2.23  116.67  114.40    2.27
# 9   0.639  1.75  112.79  110.94  1.85   1.76  112.87  110.98    1.89
# 10  0.649  1.89  118.11  116.31  1.80   1.36  117.50  116.26    1.23
# 11  0.543  1.26  116.36  115.28  1.08   1.28  116.62  115.52    1.10
# 12  0.487  0.67  116.87  116.44  0.43   0.73  117.01  116.55    0.46
# ...

# %%
team_col = pd.read_csv("C:\\Users\\ganes\\Downloads\\Team_Names.csv", header = None)

# %%
team_col
# Out:
#                          0
# 0           Boston Celtics
# 1      Cleveland Cavaliers
# 2     New Orleans Pelicans
# 3        Memphis Grizzlies
# 4            Brooklyn Nets
# 5       Philadelphia 76ers
# 6             Phoenix Suns
# 7          Milwaukee Bucks
# 8         Dallas Mavericks
# 9          New York Knicks
# 10        Sacramento Kings
# 11          Denver Nuggets
# 12         Toronto Raptors
# 13               Utah Jazz
# 14           Chicago Bulls
# 15  Portland Trail Blazers
# 16          Indiana Pacers
# 17   Golden State Warriors
# 18      Washington Wizards
# 19    Los Angeles Clippers
# 20              Miami Heat
# 21           Atlanta Hawks
# 22   Oklahoma City Thunder
# 23  Minnesota Timberwolves
# 24      Los Angeles Lakers
# 25           Orlando Magic
# 26         Detroit Pistons
# 27         Houston Rockets
# 28       Charlotte Hornets
# 29       San Antonio Spurs

# %%
df["Team"] = team_col

# %%
df = df.set_index("Team")

# %%
df
# Out:
#                          W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  \
# Team
# Boston Celtics          0.703  6.27  119.17  112.75  6.42   6.03  119.43
# Cleveland Cavaliers     0.632  5.24  116.04  110.58  5.46   5.03  115.87
# New Orleans Pelicans    0.639  4.33  114.78  110.45  4.33   4.60  114.58
# Memphis Grizzlies       0.676  4.35  117.27  112.78  4.49   4.31  117.35
# Brooklyn Nets           0.622  4.46  116.21  111.76  4.45   4.29  115.79
# Philadelphia 76ers      0.611  3.89  114.74  110.82  3.93   3.63  114.80
# Phoenix Suns            0.526  2.84  115.93  112.95  2.98   2.68  115.80
# Milwaukee Bucks         0.526  2.50  117.32  114.86  2.45   2.60  117.40
# Dallas Mavericks        0.579  2.32  116.78  114.41  2.37   2.23  116.67
# New York Knicks         0.639  1.75  112.79  110.94  1.85   1.76  112.87
# Sacramento Kings        0.649  1.89  118.11  116.31  1.80   1.36  117.50
# Denver Nuggets          0.543  1.26  116.36  115.28  1.08   1.28  116.62
# ...

# %%
df = df.sort_values("W_pred", ascending = False)

# %%
df
# Out:
#                          W/L%   MOV    ORtg    DRtg  NRtg  MOV/A  ORtg/A  \
# Team
# Boston Celtics          0.703  6.27  119.17  112.75  6.42   6.03  119.43
# Cleveland Cavaliers     0.632  5.24  116.04  110.58  5.46   5.03  115.87
# New Orleans Pelicans    0.639  4.33  114.78  110.45  4.33   4.60  114.58
# Memphis Grizzlies       0.676  4.35  117.27  112.78  4.49   4.31  117.35
# Brooklyn Nets           0.622  4.46  116.21  111.76  4.45   4.29  115.79
# Philadelphia 76ers      0.611  3.89  114.74  110.82  3.93   3.63  114.80
# Phoenix Suns            0.526  2.84  115.93  112.95  2.98   2.68  115.80
# Milwaukee Bucks         0.526  2.50  117.32  114.86  2.45   2.60  117.40
# Dallas Mavericks        0.579  2.32  116.78  114.41  2.37   2.23  116.67
# New York Knicks         0.639  1.75  112.79  110.94  1.85   1.76  112.87
# Sacramento Kings        0.649  1.89  118.11  116.31  1.80   1.36  117.50
# Denver Nuggets          0.543  1.26  116.36  115.28  1.08   1.28  116.62
# ...

# %%
df["Diff"] = df["W/L % Predictions"] - df["W/L%"]

# %%
import seaborn as sns

# %%
sns.scatterplot(data = df, y = "Diff", x = "W/L % Predictions")
# Out:
# <AxesSubplot: xlabel='W/L % Predictions', ylabel='Diff'>

# %%
print("Upon analysis of the predictive model, the model seems to be inaccurate at the extremes, but becomes more and more accurate towards the middle of the data.")
# Out:
# Upon analysis of the predictive model, the model seems to be inaccurate at the extremes, but becomes more and more accurate towards the middle of the data.
